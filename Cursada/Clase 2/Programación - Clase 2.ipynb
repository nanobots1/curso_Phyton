# %% [markdown]
# # Clase 2

# %%
def suma(a,b):
  resultado = a + b
  return resultado

#a = 3
#b = 5

resultado_suma = suma(3, 5)
print("El resultado de la suma es: ", resultado_suma)
# Out:
# El resultado de la suma es:  8

# %%
result = suma(a = 2, b = 8)
print("El resultado de la suma es: ", result)
# Out:
# El resultado de la suma es:  10

# %%
# calificaciones es una lista de tuplas
calificaciones = [("Alice", 8), ("Bob", 9), ("Charlie", 7), ("David", 6), ("Eva", 4)]

# iniciar variables
suma_calificaciones = 0
numero_estudiantes = len(calificaciones)

# sumar todas las calificaciones
for estudiante, calificacion in calificaciones:
  # suma_calificaciones = suma_calificaciones + calificacion
  suma_calificaciones += calificacion

# calcular el promedio
promedio = suma_calificaciones / numero_estudiantes

# mostrar el resultado del promedio
print("El promedio de calificaciones de los estudiantes es de: ", promedio)

# %%
def calcular_promedio(lista, suma, estudiantes):
  # sumar todas las calificaciones
  for estudiante, cal in lista:
    suma += cal

  # calcular el promedio
  promedio = suma / estudiantes

  return "El promedio de calificaciones de los estudiantes es de: ", promedio

# %%
# calificaciones es una lista de tuplas
calificaciones = [("Alice", 8), ("Bob", 9), ("Charlie", 7), ("David", 6), ("Eva", 4)]

# calificaciones es una lista de tuplas
calificaciones2 = [("Alice", 8), ("Bob", 9), ("Charlie", 7), ("David", 6), ("Eva", 4)]

# calificaciones es una lista de tuplas
calificaciones3 = [("Alice", 8), ("Bob", 9), ("Charlie", 7), ("David", 6), ("Eva", 4)]

print(calcular_promedio(calificaciones, suma = 0, estudiantes = len(calificaciones)))
print(calcular_promedio(calificaciones2, suma = 0, estudiantes = len(calificaciones2)))
print(calcular_promedio(calificaciones3, suma = 0, estudiantes = len(calificaciones3)))
# Out:
# ('El promedio de calificaciones de los estudiantes es de: ', 6.8)
# ('El promedio de calificaciones de los estudiantes es de: ', 6.8)
# ('El promedio de calificaciones de los estudiantes es de: ', 6.8)

# %% [markdown]
# variables locales

# %%
def mi_funcion():
  variable_local = 42
  print(variable_local)

mi_funcion()
# Out:
# 42

# %% [markdown]
# variables globales

# %%
variable_global = 30

def otra_funcion():
  variable_global = 40
  print(variable_global)

print(variable_global)
otra_funcion()
# Out:
# 30
# 40

# %% [markdown]
# mi modulo

# %%
import mi_modulo

mi_modulo.saludar("Christian")
# Out:
# 'Hola, Christian!'

# %%
mi_modulo.suma(10, 20)
# Out:
# 30

# %% [markdown]
# Ejercicio 1

# %%
def precio_promedio(lista):
  suma_precios = sum(lista)
  promedio = suma_precios / len(lista)
  return promedio

lista_precios = [10, 20, 50, 80, 60, 40]
promedio = precio_promedio(lista_precios)

print("El promedio de la lista de precios es: ", promedio)
# Out:
# El promedio de la lsita de precios es:  43.333333333333336

# %% [markdown]
# Recursión

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

factorial(30)
# Out:
# 265252859812191058636308480000000

# %% [markdown]
# Ejercicio 2

# %%
def suma_recursiva(n):
  if n == 1:
    return 1
  else:
    return n + suma_recursiva(n - 1)

suma_recursiva(5)
# Out:
# 15

# %% [markdown]
# Ejemplo 3

# %%
def division_segura(dividendo, divisor):
  try:
    resultado = dividendo / divisor
    return resultado
  except ZeroDivisionError:
    return "Error: no es posible dividir por cero (0)."

division_segura(10, 0)
# Out:
# 'El progrma ha terminado.'
